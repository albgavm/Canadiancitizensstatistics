# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 3250 Foundations of Data Science Jan-April 2020 <br>
# Group 7 <br>
# Member: Albert Mendoza <br>
# Prof: Irina Sedenko

# %% [markdown]
# ## 2. Merge both datasets
#
# - with both cleaned 1980-2013 and 2015-2019 datasets, Attempted to merge both into one cohesive dataset from 1980-2019
#
# ### Loading of both datasets

# %%
df1 = pd.read_csv('cleanedimmigration1519.csv', index_col=0)
df1
# Out:
#                      2015    2016    2017    2018    2019
# Country
# Total              252192  147822  106376  176486  249684
# Afghanistan          1882    1596    1187    1342    1977
# Albania               604     359     229     454     631
# Algeria              5695    2468    2004    3340    4243
# American Samoa          0       1       0       0       1
# ...                   ...     ...     ...     ...     ...
# Wallis and Futuna       0       0       0       1       0
# Yemen                 181     115      80     216     230
# Yugoslavia            183     130      60     103     108
# Zambia                129      78      54      75     104
# Zimbabwe              624     362     235     361     413
#
# [235 rows x 5 columns]

# %%
df2 = pd.read_csv('cleanedimmigration.csv', index_col=0)
df2
# Out:
#                  Region              Status  1980  1981  1982  1983  1984  \
# Country
# Afghanistan        Asia  Developing regions    16    39    39    47    71
# Albania          Europe   Developed regions     1     0     0     0     0
# Algeria          Africa  Developing regions    80    67    71    69    63
# American Samoa  Oceania  Developing regions     0     1     0     0     0
# Andorra          Europe   Developed regions     0     0     0     0     0
# ...                 ...                 ...   ...   ...   ...   ...   ...
# Vietnam            Asia  Developing regions  1191  1829  2162  3404  7583
# Western Sahara   Africa  Developing regions     0     0     0     0     0
# Yemen              Asia  Developing regions     1     2     1     6     0
# Zambia           Africa  Developing regions    11    17    11     7    16
# Zimbabwe         Africa  Developing regions    72   114   102    44    32
#
# ...

# %% [markdown]
# ### Merge both datasets
#
# - Merge through country index

# %%
immigration = pd.merge(df2, df1, how='inner', right_index = True, left_index = True)
immigration,
# Out:
# (                                         Region              Status  1980  \
#  Country
#  Afghanistan                                Asia  Developing regions    16
#  Albania                                  Europe   Developed regions     1
#  Algeria                                  Africa  Developing regions    80
#  American Samoa                          Oceania  Developing regions     0
#  Andorra                                  Europe   Developed regions     0
#  ...                                         ...                 ...   ...
#  Venezuela       Latin America and the Caribbean  Developing regions   103
#  Vietnam                                    Asia  Developing regions  1191
#  Yemen                                      Asia  Developing regions     1
#  Zambia                                   Africa  Developing regions    11
#  Zimbabwe                                 Africa  Developing regions    72
#
# ...

# %% [markdown]
# ### Making 2014 column
#
# - 2014 data was missing. I Emailed the govenment for the missing 2014 dataset, no reply since. <br>
# Because it cant be supplied by Statistics Canada I made new column "2014" as average of column '2013' and '2015'.

# %%
#make 2014 average of both 2013 and 2015
immigration ['2014'] = (immigration ['2013'] + immigration ['2015']) / 2
immigration
# Out:
#                                          Region              Status  1980  \
# Country
# Afghanistan                                Asia  Developing regions    16
# Albania                                  Europe   Developed regions     1
# Algeria                                  Africa  Developing regions    80
# American Samoa                          Oceania  Developing regions     0
# Andorra                                  Europe   Developed regions     0
# ...                                         ...                 ...   ...
# Venezuela       Latin America and the Caribbean  Developing regions   103
# Vietnam                                    Asia  Developing regions  1191
# Yemen                                      Asia  Developing regions     1
# Zambia                                   Africa  Developing regions    11
# Zimbabwe                                 Africa  Developing regions    72
#
# ...

# %%
#rearranging the columns
var = immigration['2014']
immigration.drop(labels=['2014'], axis=1,inplace = True)
immigration.insert(36, '2014', var)
immigration
# Out:
#                                          Region              Status  1980  \
# Country
# Afghanistan                                Asia  Developing regions    16
# Albania                                  Europe   Developed regions     1
# Algeria                                  Africa  Developing regions    80
# American Samoa                          Oceania  Developing regions     0
# Andorra                                  Europe   Developed regions     0
# ...                                         ...                 ...   ...
# Venezuela       Latin America and the Caribbean  Developing regions   103
# Vietnam                                    Asia  Developing regions  1191
# Yemen                                      Asia  Developing regions     1
# Zambia                                   Africa  Developing regions    11
# Zimbabwe                                 Africa  Developing regions    72
#
# ...

# %%
immigration.to_csv ('cleanedcanadaimmigration.csv', header=True)
